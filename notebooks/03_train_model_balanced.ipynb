# %% [markdown]
# # Train a RoBERTa model using a balanced dataset
#
# ## Note: This experiment did not work

# %%
import sys

sys.path.append("..")

# %%
from transformers import (
    DataCollatorWithPadding,
    RobertaConfig,
    RobertaForSequenceClassification,
    RobertaTokenizerFast,
    Trainer,
    TrainerCallback,
    TrainingArguments,
)

from adna.pylib import consts
from adna.pylib.balanced_dataset import BalancedDataset

# %% [markdown]
# ## Data augmentation parameters

# %%
REV_COMP_RATE = 0.5

# %% [markdown]
# ## Training parameters

# %%
TRAIN_EPOCHS = 50
LEARNING_RATE = 3e-5
TRAIN_BATCH_SIZE = 192
EVAL_BATCH_SIZE = 192

NUM_HIDDEN_LAYERS = 6
NUM_ATTENTION_HEADS = 6
HIDDEN_SIZE = NUM_ATTENTION_HEADS * 32

MODEL_DIR = 'train'  # Save models to this sub-directory

# %% [markdown]
# ## Get the tokenizer

# %%
tokenizer_path = str(consts.MT_DIR)
tokenizer = RobertaTokenizerFast.from_pretrained(tokenizer_path)

# %% [markdown]
# ## Get the datasets

# %%
train_dataset = BalancedDataset('train', tokenizer)
eval_dataset = BalancedDataset('val', tokenizer)

# %%
len(train_dataset.pos_records)
# Out:
# 96950

# %%
len(eval_dataset.pos_records)
# Out:
# 32034

# %% [markdown]
# ## Adjust weights

# %%
WEIGHTS = train_dataset.weights
WEIGHTS
# Out:
# [1.0, 1.0]

# %% [markdown]
# ## Build the model

# %%
config = RobertaConfig(
    vocab_size=consts.VOCAB_SIZE,
    num_hidden_layers=NUM_HIDDEN_LAYERS,
    type_vocab_size=1,
    num_labels=len(WEIGHTS),
    max_position_embeddings=consts.MAX_LENGTH,
    num_attention_heads=NUM_ATTENTION_HEADS,
    hidden_size=HIDDEN_SIZE,
)

# %%
model = RobertaForSequenceClassification(config=config)

# %% [markdown]
# ## Build the start of epoch callback

# %%
class DataResetCallback(TrainerCallback):
    def on_epoch_begin(
        self,
        args,
        state,
        control,
        train_dataloader=None,
        eval_dataloader=None,
        **kwargs,
    ):
        if train_dataloader:
            train_dataloader.dataset.sample()

# %% [markdown]
# ## Build the trainer

# %%
training_args = TrainingArguments(
    output_dir=consts.MT_DIR / MODEL_DIR,
    overwrite_output_dir=True,
    num_train_epochs=TRAIN_EPOCHS,
    learning_rate=LEARNING_RATE,
    per_device_train_batch_size=TRAIN_BATCH_SIZE,
    per_device_eval_batch_size=EVAL_BATCH_SIZE,
    evaluation_strategy="epoch",
    logging_strategy="epoch",
    save_strategy="epoch",
    seed=23,
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    tokenizer=tokenizer,
    callbacks=[DataResetCallback],
)

# %% [markdown]
# ## Train

# %%
trainer.train()
# Out:
# /museum/rafe/other/adna/.venv/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 193900
#   Num Epochs = 50
#   Instantaneous batch size per device = 192
#   Total train batch size (w. parallel, distributed & accumulation) = 192
#   Gradient Accumulation steps = 1
#   Total optimization steps = 50500
#     <div>
#
#       <progress value='50500' max='50500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50500/50500 6:41:15, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.401700</td>
#       <td>0.294142</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.291100</td>
#       <td>0.273105</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.271700</td>
#       <td>0.257891</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.262700</td>
#       <td>0.247982</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.251400</td>
#       <td>0.249661</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.239800</td>
#       <td>0.230601</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.229400</td>
#       <td>0.225182</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.223900</td>
#       <td>0.219988</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.215800</td>
#       <td>0.212062</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.207100</td>
#       <td>0.210061</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.202900</td>
#       <td>0.204392</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.196000</td>
#       <td>0.202190</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.192000</td>
#       <td>0.196488</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.188300</td>
#       <td>0.197177</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.184300</td>
#       <td>0.190357</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.178700</td>
#       <td>0.189296</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.174300</td>
#       <td>0.189054</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.170500</td>
#       <td>0.186472</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.167600</td>
#       <td>0.183476</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.164800</td>
#       <td>0.187326</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.162500</td>
#       <td>0.182944</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.160000</td>
#       <td>0.183614</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.157000</td>
#       <td>0.178103</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.155500</td>
#       <td>0.181098</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.150800</td>
#       <td>0.180119</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.150300</td>
#       <td>0.183736</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.150600</td>
#       <td>0.185093</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.144900</td>
#       <td>0.182093</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.146300</td>
#       <td>0.181559</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.141400</td>
#       <td>0.176339</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.141500</td>
#       <td>0.175496</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.139400</td>
#       <td>0.178757</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.138700</td>
#       <td>0.177764</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.137200</td>
#       <td>0.179882</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.136000</td>
#       <td>0.180184</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.133600</td>
#       <td>0.177539</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.132000</td>
#       <td>0.181762</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.132400</td>
#       <td>0.181120</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.131700</td>
#       <td>0.182179</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.129900</td>
#       <td>0.182444</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.127900</td>
#       <td>0.191703</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.129200</td>
#       <td>0.178563</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.126800</td>
#       <td>0.183464</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.129200</td>
#       <td>0.184278</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.125700</td>
#       <td>0.184391</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.126300</td>
#       <td>0.186705</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.124900</td>
#       <td>0.188921</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.123900</td>
#       <td>0.188639</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.125200</td>
#       <td>0.188386</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.123900</td>
#       <td>0.185881</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-1010
# Configuration saved in ../data/UF46992/train/checkpoint-1010/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-1010/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-1010/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-1010/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-2020
# Configuration saved in ../data/UF46992/train/checkpoint-2020/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-2020/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-2020/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-2020/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-3030
# Configuration saved in ../data/UF46992/train/checkpoint-3030/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-3030/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-3030/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-3030/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-4040
# Configuration saved in ../data/UF46992/train/checkpoint-4040/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-4040/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-4040/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-4040/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-5050
# Configuration saved in ../data/UF46992/train/checkpoint-5050/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-5050/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-5050/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-5050/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-6060
# Configuration saved in ../data/UF46992/train/checkpoint-6060/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-6060/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-6060/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-6060/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-7070
# Configuration saved in ../data/UF46992/train/checkpoint-7070/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-7070/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-7070/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-7070/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-8080
# Configuration saved in ../data/UF46992/train/checkpoint-8080/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-8080/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-8080/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-8080/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-9090
# Configuration saved in ../data/UF46992/train/checkpoint-9090/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-9090/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-9090/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-9090/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-10100
# Configuration saved in ../data/UF46992/train/checkpoint-10100/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-10100/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-10100/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-10100/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-11110
# Configuration saved in ../data/UF46992/train/checkpoint-11110/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-11110/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-11110/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-11110/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-12120
# Configuration saved in ../data/UF46992/train/checkpoint-12120/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-12120/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-12120/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-12120/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-13130
# Configuration saved in ../data/UF46992/train/checkpoint-13130/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-13130/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-13130/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-13130/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-14140
# Configuration saved in ../data/UF46992/train/checkpoint-14140/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-14140/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-14140/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-14140/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-15150
# Configuration saved in ../data/UF46992/train/checkpoint-15150/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-15150/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-15150/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-15150/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-16160
# Configuration saved in ../data/UF46992/train/checkpoint-16160/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-16160/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-16160/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-16160/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-17170
# Configuration saved in ../data/UF46992/train/checkpoint-17170/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-17170/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-17170/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-17170/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-18180
# Configuration saved in ../data/UF46992/train/checkpoint-18180/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-18180/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-18180/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-18180/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-19190
# Configuration saved in ../data/UF46992/train/checkpoint-19190/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-19190/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-19190/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-19190/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-20200
# Configuration saved in ../data/UF46992/train/checkpoint-20200/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-20200/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-20200/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-20200/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-21210
# Configuration saved in ../data/UF46992/train/checkpoint-21210/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-21210/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-21210/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-21210/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-22220
# Configuration saved in ../data/UF46992/train/checkpoint-22220/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-22220/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-22220/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-22220/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-23230
# Configuration saved in ../data/UF46992/train/checkpoint-23230/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-23230/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-23230/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-23230/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-24240
# Configuration saved in ../data/UF46992/train/checkpoint-24240/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-24240/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-24240/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-24240/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-25250
# Configuration saved in ../data/UF46992/train/checkpoint-25250/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-25250/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-25250/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-25250/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-26260
# Configuration saved in ../data/UF46992/train/checkpoint-26260/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-26260/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-26260/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-26260/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-27270
# Configuration saved in ../data/UF46992/train/checkpoint-27270/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-27270/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-27270/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-27270/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-28280
# Configuration saved in ../data/UF46992/train/checkpoint-28280/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-28280/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-28280/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-28280/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-29290
# Configuration saved in ../data/UF46992/train/checkpoint-29290/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-29290/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-29290/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-29290/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-30300
# Configuration saved in ../data/UF46992/train/checkpoint-30300/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-30300/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-30300/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-30300/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-31310
# Configuration saved in ../data/UF46992/train/checkpoint-31310/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-31310/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-31310/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-31310/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-32320
# Configuration saved in ../data/UF46992/train/checkpoint-32320/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-32320/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-32320/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-32320/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-33330
# Configuration saved in ../data/UF46992/train/checkpoint-33330/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-33330/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-33330/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-33330/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-34340
# Configuration saved in ../data/UF46992/train/checkpoint-34340/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-34340/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-34340/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-34340/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-35350
# Configuration saved in ../data/UF46992/train/checkpoint-35350/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-35350/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-35350/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-35350/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-36360
# Configuration saved in ../data/UF46992/train/checkpoint-36360/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-36360/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-36360/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-36360/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-37370
# Configuration saved in ../data/UF46992/train/checkpoint-37370/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-37370/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-37370/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-37370/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-38380
# Configuration saved in ../data/UF46992/train/checkpoint-38380/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-38380/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-38380/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-38380/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-39390
# Configuration saved in ../data/UF46992/train/checkpoint-39390/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-39390/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-39390/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-39390/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-40400
# Configuration saved in ../data/UF46992/train/checkpoint-40400/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-40400/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-40400/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-40400/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-41410
# Configuration saved in ../data/UF46992/train/checkpoint-41410/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-41410/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-41410/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-41410/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-42420
# Configuration saved in ../data/UF46992/train/checkpoint-42420/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-42420/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-42420/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-42420/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-43430
# Configuration saved in ../data/UF46992/train/checkpoint-43430/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-43430/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-43430/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-43430/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-44440
# Configuration saved in ../data/UF46992/train/checkpoint-44440/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-44440/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-44440/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-44440/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-45450
# Configuration saved in ../data/UF46992/train/checkpoint-45450/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-45450/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-45450/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-45450/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-46460
# Configuration saved in ../data/UF46992/train/checkpoint-46460/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-46460/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-46460/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-46460/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-47470
# Configuration saved in ../data/UF46992/train/checkpoint-47470/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-47470/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-47470/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-47470/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-48480
# Configuration saved in ../data/UF46992/train/checkpoint-48480/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-48480/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-48480/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-48480/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-49490
# Configuration saved in ../data/UF46992/train/checkpoint-49490/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-49490/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-49490/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-49490/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 64068
#   Batch size = 192
# Saving model checkpoint to ../data/UF46992/train/checkpoint-50500
# Configuration saved in ../data/UF46992/train/checkpoint-50500/config.json
# Model weights saved in ../data/UF46992/train/checkpoint-50500/pytorch_model.bin
# tokenizer config file saved in ../data/UF46992/train/checkpoint-50500/tokenizer_config.json
# Special tokens file saved in ../data/UF46992/train/checkpoint-50500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=50500, training_loss=0.1709773406982422, metrics={'train_runtime': 24076.6204, 'train_samples_per_second': 402.673, 'train_steps_per_second': 2.097, 'total_flos': 4.670614725e+16, 'train_loss': 0.1709773406982422, 'epoch': 50.0})

# %% [markdown]
# ### It looks like epoch 42 is best
#
# Path = `../data/UF46992/train/checkpoint-42420`
